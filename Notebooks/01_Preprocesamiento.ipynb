# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Valor total de mercado de la oferta circulante de todas las criptomonedas,
#incluidas las stablecoins y los tokens.
df_marketcap = pd.read_csv("../Data/Raw/mc.csv", parse_dates = ['DateTime'], sep=";")
df_marketcap
# Out:
#                 DateTime        Market cap
# 0    2013-04-29 02:00:00        1583440000
# 1    2013-05-01 02:00:00        1637389952
# 2    2013-05-03 02:00:00        1275410048
# 3    2013-05-05 02:00:00        1335379968
# 4    2013-05-07 02:00:00        1313900032
# ...                  ...               ...
# 1925 2023-11-15 01:00:00  1364502154648,59
# 1926 2023-11-17 01:00:00  1381335242906,16
# 1927 2023-11-19 01:00:00  1390730073576,85
# 1928 2023-11-21 01:00:00  1417560728672,17
# 1929 2023-11-23 01:00:00  1418535373207,75
#
# [1930 rows x 2 columns]

# %%
df_marketcap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1930 entries, 0 to 1929
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DateTime    1930 non-null   datetime64[ns]
#  1   Market cap  1930 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 30.3+ KB

# %%
print(df_marketcap['DateTime'].min())
print(df_marketcap['DateTime'].max())
# Out:
# 2013-04-29 02:00:00
# 2023-11-23 01:00:00

# %%
df_marketcap.set_index('DateTime', inplace=True)
df_marketcap.head()
# Out:
#                      Market cap
# DateTime
# 2013-04-29 02:00:00  1583440000
# 2013-05-01 02:00:00  1637389952
# 2013-05-03 02:00:00  1275410048
# 2013-05-05 02:00:00  1335379968
# 2013-05-07 02:00:00  1313900032

# %%
df_marketcap['Market cap'] = df_marketcap['Market cap'].str.replace(',', '.').astype(float)

# %%
plt.figure(figsize=(20,10))
plt.plot(df_marketcap);

# %%
#Volumen total de operaciones al contado en 24 horas de todas las criptomonedas,
#incluidas las stablecoins y los tokens.
df_volume = pd.read_csv("../Data/Raw/volume24h.csv", parse_dates = ['DateTime'], sep=";")
df_volume
# Out:
#                 DateTime    Volume (24h)
# 0    2013-04-29 02:00:00               0
# 1    2013-05-01 02:00:00               0
# 2    2013-05-03 02:00:00               0
# 3    2013-05-05 02:00:00               0
# 4    2013-05-07 02:00:00               0
# ...                  ...             ...
# 1925 2023-11-15 01:00:00  65405333333,81
# 1926 2023-11-17 01:00:00  71621942772,77
# 1927 2023-11-19 01:00:00  40607308190,97
# 1928 2023-11-21 01:00:00  55029365347,64
# 1929 2023-11-23 01:00:00  59415066531,37
#
# [1930 rows x 2 columns]

# %%
df_volume.set_index('DateTime', inplace=True)
df_volume['Volume (24h)'] = df_volume['Volume (24h)'].str.replace(',', '.').astype(float)

# %%
#La capitalización bursátil total de Bitcoin comparada con la
#capitalización bursátil total de todas las criptomonedas combinadas.
df_dom = pd.read_csv("../Data/Raw/btc_dominance.csv", parse_dates = ['DateTime'], sep=";")
df_dom
# Out:
#                DateTime                 BTC                 ETH  \
# 0   2013-05-05 02:00:00  1254762149,4585037                   0
# 1   2013-05-12 02:00:00  1288631442,1985626                   0
# 2   2013-05-19 02:00:00  1376371582,9864502                   0
# 3   2013-05-26 02:00:00  1478025338,3468628                   0
# 4   2013-06-02 02:00:00  1451925896,7685697                   0
# ..                  ...                 ...                 ...
# 546 2023-10-22 02:00:00   584019984977,6497   195948847306,6615
# 547 2023-10-29 02:00:00   665656548615,5605   213663634184,2632
# 548 2023-11-05 01:00:00   685425049680,7308   223385918567,2427
# 549 2023-11-12 01:00:00   725589121192,4537  246911725799,46518
# 550 2023-11-19 01:00:00    715108559322,432  236077730418,46545
#
#                   USDT                 BNB                 XRP  \
# 0                    0                   0                   0
# 1                    0                   0                   0
# 2                    0                   0                   0
# 3                    0                   0                   0
# 4                    0                   0                   0
# ..                 ...                 ...                 ...
# 546  84181185815,08122  32513704451,181694   27853358689,07976
# 547   84557956914,1351   34252961268,42906  29210414056,590923
# 548  85430312992,87839  36020704252,850746  33036985122,195488
# 549   86668304904,3247   38143057154,32209  35558236860,164444
# 550  87730704510,39658   37161761285,19125  32831924703,885918
#
#                   Otros
# 0     80617818,54149635
# 1     74918509,80143735
# 2      72448385,0135498
# 3     70654597,65313727
# 4     59084151,23143019
# ..                  ...
# 546   211254922723,2262
# 547  228438512734,17108
# 548   245716825929,4018
# 549  281995525559,63983
# 550   281819393336,4787
#
# [551 rows x 7 columns]

# %%
df_dom.set_index('DateTime', inplace=True)
df_dom['BTC'] = df_dom['BTC'].str.replace(',', '.').astype(float)
df_dom['ETH'] = df_dom['ETH'].str.replace(',', '.').astype(float)
df_dom['USDT'] = df_dom['USDT'].str.replace(',', '.').astype(float)
df_dom['BNB'] = df_dom['BNB'].str.replace(',', '.').astype(float)
df_dom['XRP'] = df_dom['XRP'].str.replace(',', '.').astype(float)
df_dom['Otros'] = df_dom['Otros'].str.replace(',', '.').astype(float)

# %%
df_dom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 551 entries, 2013-05-05 02:00:00 to 2023-11-19 01:00:00
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   BTC     551 non-null    float64
#  1   ETH     551 non-null    float64
#  2   USDT    551 non-null    float64
#  3   BNB     551 non-null    float64
#  4   XRP     551 non-null    float64
#  5   Otros   551 non-null    float64
# dtypes: float64(6)
# memory usage: 30.1 KB

# %%
df_dom["Total"] = df_dom.sum(axis=1)
df_dom
# Out:
#                               BTC           ETH          USDT           BNB  \
# DateTime
# 2013-05-05 02:00:00  1.254762e+09  0.000000e+00  0.000000e+00  0.000000e+00
# 2013-05-12 02:00:00  1.288631e+09  0.000000e+00  0.000000e+00  0.000000e+00
# 2013-05-19 02:00:00  1.376372e+09  0.000000e+00  0.000000e+00  0.000000e+00
# 2013-05-26 02:00:00  1.478025e+09  0.000000e+00  0.000000e+00  0.000000e+00
# 2013-06-02 02:00:00  1.451926e+09  0.000000e+00  0.000000e+00  0.000000e+00
# ...                           ...           ...           ...           ...
# 2023-10-22 02:00:00  5.840200e+11  1.959488e+11  8.418119e+10  3.251370e+10
# 2023-10-29 02:00:00  6.656565e+11  2.136636e+11  8.455796e+10  3.425296e+10
# 2023-11-05 01:00:00  6.854250e+11  2.233859e+11  8.543031e+10  3.602070e+10
# 2023-11-12 01:00:00  7.255891e+11  2.469117e+11  8.666830e+10  3.814306e+10
# 2023-11-19 01:00:00  7.151086e+11  2.360777e+11  8.773070e+10  3.716176e+10
#
#                               XRP         Otros         Total
# DateTime
# 2013-05-05 02:00:00  0.000000e+00  8.061782e+07  1.335380e+09
# 2013-05-12 02:00:00  0.000000e+00  7.491851e+07  1.363550e+09
# 2013-05-19 02:00:00  0.000000e+00  7.244839e+07  1.448820e+09
# 2013-05-26 02:00:00  0.000000e+00  7.065460e+07  1.548680e+09
# 2013-06-02 02:00:00  0.000000e+00  5.908415e+07  1.511010e+09
# ...                           ...           ...           ...
# 2023-10-22 02:00:00  2.785336e+10  2.112549e+11  1.135772e+12
# 2023-10-29 02:00:00  2.921041e+10  2.284385e+11  1.255780e+12
# 2023-11-05 01:00:00  3.303699e+10  2.457168e+11  1.309016e+12
# 2023-11-12 01:00:00  3.555824e+10  2.819955e+11  1.414866e+12
# 2023-11-19 01:00:00  3.283192e+10  2.818194e+11  1.390730e+12
#
# [551 rows x 7 columns]

# %%
df_dompercentage = df_dom[['BTC', 'ETH', 'USDT', 'BNB', 'XRP', 'Otros']].div(df_dom['Total'], axis=0) * 100

# %%
df_dompercentage.head()
# Out:
#                            BTC  ETH  USDT  BNB  XRP     Otros
# DateTime
# 2013-05-05 02:00:00  93.962930  0.0   0.0  0.0  0.0  6.037070
# 2013-05-12 02:00:00  94.505628  0.0   0.0  0.0  0.0  5.494372
# 2013-05-19 02:00:00  94.999490  0.0   0.0  0.0  0.0  5.000510
# 2013-05-26 02:00:00  95.437753  0.0   0.0  0.0  0.0  4.562247
# 2013-06-02 02:00:00  96.089758  0.0   0.0  0.0  0.0  3.910242

# %%
df_mcbtc = pd.read_csv("../Data/Raw/mcbtc.csv", parse_dates = ['DateTime'], sep=";")
df_mcbtc
# Out:
#                 DateTime          Market cap
# 0    2013-04-29 02:00:00  1491167008,9733124
# 1    2013-05-01 02:00:00  1542817108,0902102
# 2    2013-05-03 02:00:00       1180068281,25
# 3    2013-05-05 02:00:00  1254762149,4585037
# 4    2013-05-07 02:00:00          1248466950
# ...                  ...                 ...
# 1925 2023-11-15 01:00:00    694695866030,514
# 1926 2023-11-17 01:00:00   706813666595,3916
# 1927 2023-11-19 01:00:00    715108559322,432
# 1928 2023-11-21 01:00:00   732455077417,0979
# 1929 2023-11-23 01:00:00   731572513322,5349
#
# [1930 rows x 2 columns]

# %%
df_mcbtc.set_index('DateTime', inplace=True)
df_mcbtc['Market cap BTC'] = df_mcbtc['Market cap'].str.replace(',', '.').astype(float)
df_mcbtc = df_mcbtc.drop(columns="Market cap")
df_mcbtc
# Out:
#                      Market cap BTC
# DateTime
# 2013-04-29 02:00:00    1.491167e+09
# 2013-05-01 02:00:00    1.542817e+09
# 2013-05-03 02:00:00    1.180068e+09
# 2013-05-05 02:00:00    1.254762e+09
# 2013-05-07 02:00:00    1.248467e+09
# ...                             ...
# 2023-11-15 01:00:00    6.946959e+11
# 2023-11-17 01:00:00    7.068137e+11
# 2023-11-19 01:00:00    7.151086e+11
# 2023-11-21 01:00:00    7.324551e+11
# 2023-11-23 01:00:00    7.315725e+11
#
# [1930 rows x 1 columns]

# %%
df_mceth = pd.read_csv("../Data/Raw/mceth.csv", parse_dates = ['DateTime'], sep=";")
df_mceth
# Out:
#                 DateTime          Market cap
# 0    2013-04-29 02:00:00                   0
# 1    2013-05-01 02:00:00                   0
# 2    2013-05-03 02:00:00                   0
# 3    2013-05-05 02:00:00                   0
# 4    2013-05-07 02:00:00                   0
# ...                  ...                 ...
# 1925 2023-11-15 01:00:00  238046848902,36615
# 1926 2023-11-17 01:00:00  235923781350,10202
# 1927 2023-11-19 01:00:00  236077730418,46545
# 1928 2023-11-21 01:00:00  243177324136,70392
# 1929 2023-11-23 01:00:00   248182604665,9441
#
# [1930 rows x 2 columns]

# %%
df_mceth.set_index('DateTime', inplace=True)
df_mceth['Market cap ETH'] = df_mceth['Market cap'].str.replace(',', '.').astype(float)
df_mceth = df_mceth.drop(columns="Market cap")
df_mceth
# Out:
#                      Market cap ETH
# DateTime
# 2013-04-29 02:00:00    0.000000e+00
# 2013-05-01 02:00:00    0.000000e+00
# 2013-05-03 02:00:00    0.000000e+00
# 2013-05-05 02:00:00    0.000000e+00
# 2013-05-07 02:00:00    0.000000e+00
# ...                             ...
# 2023-11-15 01:00:00    2.380468e+11
# 2023-11-17 01:00:00    2.359238e+11
# 2023-11-19 01:00:00    2.360777e+11
# 2023-11-21 01:00:00    2.431773e+11
# 2023-11-23 01:00:00    2.481826e+11
#
# [1930 rows x 1 columns]

# %%
df_mcusdt = pd.read_csv("../Data/Raw/mcusdt.csv", parse_dates = ['DateTime'], sep=";")
df_mcusdt
# Out:
#                 DateTime         Market cap
# 0    2013-04-29 02:00:00                  0
# 1    2013-05-01 02:00:00                  0
# 2    2013-05-03 02:00:00                  0
# 3    2013-05-05 02:00:00                  0
# 4    2013-05-07 02:00:00                  0
# ...                  ...                ...
# 1925 2023-11-15 01:00:00  87099020286,11885
# 1926 2023-11-17 01:00:00  87450691905,53871
# 1927 2023-11-19 01:00:00  87730704510,39658
# 1928 2023-11-21 01:00:00  87761587870,46349
# 1929 2023-11-23 01:00:00  88340545055,67949
#
# [1930 rows x 2 columns]

# %%
df_mcusdt.set_index('DateTime', inplace=True)
df_mcusdt['Market cap USDT'] = df_mcusdt['Market cap'].str.replace(',', '.').astype(float)
df_mcusdt = df_mcusdt.drop(columns="Market cap")
df_mcusdt
# Out:
#                      Market cap USDT
# DateTime
# 2013-04-29 02:00:00     0.000000e+00
# 2013-05-01 02:00:00     0.000000e+00
# 2013-05-03 02:00:00     0.000000e+00
# 2013-05-05 02:00:00     0.000000e+00
# 2013-05-07 02:00:00     0.000000e+00
# ...                              ...
# 2023-11-15 01:00:00     8.709902e+10
# 2023-11-17 01:00:00     8.745069e+10
# 2023-11-19 01:00:00     8.773070e+10
# 2023-11-21 01:00:00     8.776159e+10
# 2023-11-23 01:00:00     8.834055e+10
#
# [1930 rows x 1 columns]

# %%
df_mcbnb = pd.read_csv("../Data/Raw/mcbnb.csv", parse_dates = ['DateTime'], sep=";")
df_mcbnb
# Out:
#                 DateTime          Market cap
# 0    2013-04-29 02:00:00                   0
# 1    2013-05-01 02:00:00                   0
# 2    2013-05-03 02:00:00                   0
# 3    2013-05-05 02:00:00                   0
# 4    2013-05-07 02:00:00                   0
# ...                  ...                 ...
# 1925 2023-11-15 01:00:00   36754352394,58466
# 1926 2023-11-17 01:00:00   36839064710,31718
# 1927 2023-11-19 01:00:00   37161761285,19125
# 1928 2023-11-21 01:00:00   38477862689,04214
# 1929 2023-11-23 01:00:00  35815763791,689865
#
# [1930 rows x 2 columns]

# %%
df_mcbnb.set_index('DateTime', inplace=True)
df_mcbnb['Market cap BNB'] = df_mcbnb['Market cap'].str.replace(',', '.').astype(float)
df_mcbnb = df_mcbnb.drop(columns="Market cap")
df_mcbnb
# Out:
#                      Market cap BNB
# DateTime
# 2013-04-29 02:00:00    0.000000e+00
# 2013-05-01 02:00:00    0.000000e+00
# 2013-05-03 02:00:00    0.000000e+00
# 2013-05-05 02:00:00    0.000000e+00
# 2013-05-07 02:00:00    0.000000e+00
# ...                             ...
# 2023-11-15 01:00:00    3.675435e+10
# 2023-11-17 01:00:00    3.683906e+10
# 2023-11-19 01:00:00    3.716176e+10
# 2023-11-21 01:00:00    3.847786e+10
# 2023-11-23 01:00:00    3.581576e+10
#
# [1930 rows x 1 columns]

# %%
df_mcxrp = pd.read_csv("../Data/Raw/mcxrp.csv", parse_dates = ['DateTime'], sep=";")
df_mcxrp
# Out:
#                 DateTime          Market cap
# 0    2013-04-29 02:00:00                   0
# 1    2013-05-01 02:00:00                   0
# 2    2013-05-03 02:00:00                   0
# 3    2013-05-05 02:00:00                   0
# 4    2013-05-07 02:00:00                   0
# ...                  ...                 ...
# 1925 2023-11-15 01:00:00  33786566359,719784
# 1926 2023-11-17 01:00:00   32886285716,08037
# 1927 2023-11-19 01:00:00  32831924703,885918
# 1928 2023-11-21 01:00:00  32920382997,371902
# 1929 2023-11-23 01:00:00  32868098043,411392
#
# [1930 rows x 2 columns]

# %%
df_mcxrp.set_index('DateTime', inplace=True)
df_mcxrp['Market cap XRP'] = df_mcxrp['Market cap'].str.replace(',', '.').astype(float)
df_mcxrp = df_mcxrp.drop(columns="Market cap")
df_mcxrp
# Out:
#                      Market cap XRP
# DateTime
# 2013-04-29 02:00:00    0.000000e+00
# 2013-05-01 02:00:00    0.000000e+00
# 2013-05-03 02:00:00    0.000000e+00
# 2013-05-05 02:00:00    0.000000e+00
# 2013-05-07 02:00:00    0.000000e+00
# ...                             ...
# 2023-11-15 01:00:00    3.378657e+10
# 2023-11-17 01:00:00    3.288629e+10
# 2023-11-19 01:00:00    3.283192e+10
# 2023-11-21 01:00:00    3.292038e+10
# 2023-11-23 01:00:00    3.286810e+10
#
# [1930 rows x 1 columns]

# %%
df_mcusdc = pd.read_csv("../Data/Raw/mcusdc.csv", parse_dates = ['DateTime'], sep=";")
df_mcusdc
# Out:
#                 DateTime          Market cap
# 0    2013-04-29 02:00:00                   0
# 1    2013-05-01 02:00:00                   0
# 2    2013-05-03 02:00:00                   0
# 3    2013-05-05 02:00:00                   0
# 4    2013-05-07 02:00:00                   0
# ...                  ...                 ...
# 1925 2023-11-15 01:00:00   23891933019,08411
# 1926 2023-11-17 01:00:00  24173873088,947666
# 1927 2023-11-19 01:00:00   24415630412,19631
# 1928 2023-11-21 01:00:00  24515852498,158184
# 1929 2023-11-23 01:00:00  24409877755,732834
#
# [1930 rows x 2 columns]

# %%
df_mcusdc.set_index('DateTime', inplace=True)
df_mcusdc['Market cap USDC'] = df_mcusdc['Market cap'].str.replace(',', '.').astype(float)
df_mcusdc = df_mcusdc.drop(columns="Market cap")
df_mcusdc
# Out:
#                      Market cap USDC
# DateTime
# 2013-04-29 02:00:00     0.000000e+00
# 2013-05-01 02:00:00     0.000000e+00
# 2013-05-03 02:00:00     0.000000e+00
# 2013-05-05 02:00:00     0.000000e+00
# 2013-05-07 02:00:00     0.000000e+00
# ...                              ...
# 2023-11-15 01:00:00     2.389193e+10
# 2023-11-17 01:00:00     2.417387e+10
# 2023-11-19 01:00:00     2.441563e+10
# 2023-11-21 01:00:00     2.451585e+10
# 2023-11-23 01:00:00     2.440988e+10
#
# [1930 rows x 1 columns]

# %%
df_mcsol = pd.read_csv("../Data/Raw/mcsol.csv", parse_dates = ['DateTime'], sep=";")
df_mcsol
# Out:
#                 DateTime          Market cap
# 0    2013-04-29 02:00:00                   0
# 1    2013-05-01 02:00:00                   0
# 2    2013-05-03 02:00:00                   0
# 3    2013-05-05 02:00:00                   0
# 4    2013-05-07 02:00:00                   0
# ...                  ...                 ...
# 1925 2023-11-15 01:00:00   24008989629,95201
# 1926 2023-11-17 01:00:00  24479722067,792194
# 1927 2023-11-19 01:00:00  24748165411,799564
# 1928 2023-11-21 01:00:00  23916047918,573635
# 1929 2023-11-23 01:00:00   24361492021,87241
#
# [1930 rows x 2 columns]

# %%
df_mcsol.set_index('DateTime', inplace=True)
df_mcsol['Market cap SOL'] = df_mcsol['Market cap'].str.replace(',', '.').astype(float)
df_mcsol = df_mcsol.drop(columns="Market cap")
df_mcsol
# Out:
#                      Market cap SOL
# DateTime
# 2013-04-29 02:00:00    0.000000e+00
# 2013-05-01 02:00:00    0.000000e+00
# 2013-05-03 02:00:00    0.000000e+00
# 2013-05-05 02:00:00    0.000000e+00
# 2013-05-07 02:00:00    0.000000e+00
# ...                             ...
# 2023-11-15 01:00:00    2.400899e+10
# 2023-11-17 01:00:00    2.447972e+10
# 2023-11-19 01:00:00    2.474817e+10
# 2023-11-21 01:00:00    2.391605e+10
# 2023-11-23 01:00:00    2.436149e+10
#
# [1930 rows x 1 columns]

# %%
df_mcada = pd.read_csv("../Data/Raw/mcada.csv", parse_dates = ['DateTime'], sep=";")
df_mcada
# Out:
#                 DateTime          Market cap
# 0    2013-04-29 02:00:00                   0
# 1    2013-05-01 02:00:00                   0
# 2    2013-05-03 02:00:00                   0
# 3    2013-05-05 02:00:00                   0
# 4    2013-05-07 02:00:00                   0
# ...                  ...                 ...
# 1925 2023-11-15 01:00:00  12623354366,873348
# 1926 2023-11-17 01:00:00   13116227158,30211
# 1927 2023-11-19 01:00:00  13324261384,595125
# 1928 2023-11-21 01:00:00   13433894407,06461
# 1929 2023-11-23 01:00:00  13433476384,459835
#
# [1930 rows x 2 columns]

# %%
df_mcada.set_index('DateTime', inplace=True)
df_mcada['Market cap ADA'] = df_mcada['Market cap'].str.replace(',', '.').astype(float)
df_mcada = df_mcada.drop(columns="Market cap")
df_mcada
# Out:
#                      Market cap ADA
# DateTime
# 2013-04-29 02:00:00    0.000000e+00
# 2013-05-01 02:00:00    0.000000e+00
# 2013-05-03 02:00:00    0.000000e+00
# 2013-05-05 02:00:00    0.000000e+00
# 2013-05-07 02:00:00    0.000000e+00
# ...                             ...
# 2023-11-15 01:00:00    1.262335e+10
# 2023-11-17 01:00:00    1.311623e+10
# 2023-11-19 01:00:00    1.332426e+10
# 2023-11-21 01:00:00    1.343389e+10
# 2023-11-23 01:00:00    1.343348e+10
#
# [1930 rows x 1 columns]

# %%
df_mcdoge = pd.read_csv("../Data/Raw/mcdoge.csv", parse_dates = ['DateTime'], sep=";")
df_mcdoge
# Out:
#                 DateTime          Market cap
# 0    2013-04-29 02:00:00                   0
# 1    2013-05-01 02:00:00                   0
# 2    2013-05-03 02:00:00                   0
# 3    2013-05-05 02:00:00                   0
# 4    2013-05-07 02:00:00                   0
# ...                  ...                 ...
# 1925 2023-11-15 01:00:00  10276577823,778168
# 1926 2023-11-17 01:00:00   11253085469,00526
# 1927 2023-11-19 01:00:00  11406901434,848097
# 1928 2023-11-21 01:00:00  11051976181,235575
# 1929 2023-11-23 01:00:00  10754758869,983622
#
# [1930 rows x 2 columns]

# %%
df_mcdoge.set_index('DateTime', inplace=True)
df_mcdoge['Market cap DOGE'] = df_mcdoge['Market cap'].str.replace(',', '.').astype(float)
df_mcdoge = df_mcdoge.drop(columns="Market cap")
df_mcdoge
# Out:
#                      Market cap DOGE
# DateTime
# 2013-04-29 02:00:00     0.000000e+00
# 2013-05-01 02:00:00     0.000000e+00
# 2013-05-03 02:00:00     0.000000e+00
# 2013-05-05 02:00:00     0.000000e+00
# 2013-05-07 02:00:00     0.000000e+00
# ...                              ...
# 2023-11-15 01:00:00     1.027658e+10
# 2023-11-17 01:00:00     1.125309e+10
# 2023-11-19 01:00:00     1.140690e+10
# 2023-11-21 01:00:00     1.105198e+10
# 2023-11-23 01:00:00     1.075476e+10
#
# [1930 rows x 1 columns]

# %%
df_mctrx = pd.read_csv("../Data/Raw/mctrx.csv", parse_dates = ['DateTime'], sep=";")
df_mctrx
# Out:
#                 DateTime         Market cap
# 0    2013-04-29 02:00:00                  0
# 1    2013-05-01 02:00:00                  0
# 2    2013-05-03 02:00:00                  0
# 3    2013-05-05 02:00:00                  0
# 4    2013-05-07 02:00:00                  0
# ...                  ...                ...
# 1925 2023-11-15 01:00:00  9068945864,192478
# 1926 2023-11-17 01:00:00  9078347152,606707
# 1927 2023-11-19 01:00:00  9129964371,164316
# 1928 2023-11-21 01:00:00  8960597527,883825
# 1929 2023-11-23 01:00:00    8968882188,7678
#
# [1930 rows x 2 columns]

# %%
df_mctrx.set_index('DateTime', inplace=True)
df_mctrx['Market cap TRX'] = df_mctrx['Market cap'].str.replace(',', '.').astype(float)
df_mctrx = df_mctrx.drop(columns="Market cap")
df_mctrx
# Out:
#                      Market cap TRX
# DateTime
# 2013-04-29 02:00:00    0.000000e+00
# 2013-05-01 02:00:00    0.000000e+00
# 2013-05-03 02:00:00    0.000000e+00
# 2013-05-05 02:00:00    0.000000e+00
# 2013-05-07 02:00:00    0.000000e+00
# ...                             ...
# 2023-11-15 01:00:00    9.068946e+09
# 2023-11-17 01:00:00    9.078347e+09
# 2023-11-19 01:00:00    9.129964e+09
# 2023-11-21 01:00:00    8.960598e+09
# 2023-11-23 01:00:00    8.968882e+09
#
# [1930 rows x 1 columns]

# %%
plt.figure(figsize=(12, 6))
plt.stackplot(df_dompercentage.index, df_dompercentage.T, labels=df_dompercentage.columns, alpha=0.9)
plt.xlabel('Año')
plt.ylabel('Porcentaje del Total (%)')
plt.title('Distribución del Market Cap por Criptomoneda a lo largo del Tiempo')

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %%
dfs = [df_marketcap,df_volume,df_mcbtc, df_mceth, df_mcusdt, df_mcbnb, df_mcxrp, df_mcusdc, df_mcsol, df_mcada, df_mcdoge, df_mctrx]

result_df = pd.concat(dfs, axis=1)
result_df
# Out:
#                        Market cap  Volume (24h)  Market cap BTC  \
# DateTime
# 2013-04-29 02:00:00  1.583440e+09  0.000000e+00    1.491167e+09
# 2013-05-01 02:00:00  1.637390e+09  0.000000e+00    1.542817e+09
# 2013-05-03 02:00:00  1.275410e+09  0.000000e+00    1.180068e+09
# 2013-05-05 02:00:00  1.335380e+09  0.000000e+00    1.254762e+09
# 2013-05-07 02:00:00  1.313900e+09  0.000000e+00    1.248467e+09
# ...                           ...           ...             ...
# 2023-11-15 01:00:00  1.364502e+12  6.540533e+10    6.946959e+11
# 2023-11-17 01:00:00  1.381335e+12  7.162194e+10    7.068137e+11
# 2023-11-19 01:00:00  1.390730e+12  4.060731e+10    7.151086e+11
# 2023-11-21 01:00:00  1.417561e+12  5.502937e+10    7.324551e+11
# 2023-11-23 01:00:00  1.418535e+12  5.941507e+10    7.315725e+11
#
#                      Market cap ETH  Market cap USDT  Market cap BNB  \
# DateTime
# 2013-04-29 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-01 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-03 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-05 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-07 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# ...                             ...              ...             ...
# 2023-11-15 01:00:00    2.380468e+11     8.709902e+10    3.675435e+10
# 2023-11-17 01:00:00    2.359238e+11     8.745069e+10    3.683906e+10
# 2023-11-19 01:00:00    2.360777e+11     8.773070e+10    3.716176e+10
# 2023-11-21 01:00:00    2.431773e+11     8.776159e+10    3.847786e+10
# 2023-11-23 01:00:00    2.481826e+11     8.834055e+10    3.581576e+10
#
#                      Market cap XRP  Market cap USDC  Market cap SOL  \
# DateTime
# 2013-04-29 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-01 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-03 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-05 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-07 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# ...                             ...              ...             ...
# 2023-11-15 01:00:00    3.378657e+10     2.389193e+10    2.400899e+10
# 2023-11-17 01:00:00    3.288629e+10     2.417387e+10    2.447972e+10
# 2023-11-19 01:00:00    3.283192e+10     2.441563e+10    2.474817e+10
# 2023-11-21 01:00:00    3.292038e+10     2.451585e+10    2.391605e+10
# 2023-11-23 01:00:00    3.286810e+10     2.440988e+10    2.436149e+10
#
#                      Market cap ADA  Market cap DOGE  Market cap TRX
# DateTime
# 2013-04-29 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-01 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-03 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-05 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-07 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# ...                             ...              ...             ...
# 2023-11-15 01:00:00    1.262335e+10     1.027658e+10    9.068946e+09
# 2023-11-17 01:00:00    1.311623e+10     1.125309e+10    9.078347e+09
# 2023-11-19 01:00:00    1.332426e+10     1.140690e+10    9.129964e+09
# 2023-11-21 01:00:00    1.343389e+10     1.105198e+10    8.960598e+09
# 2023-11-23 01:00:00    1.343348e+10     1.075476e+10    8.968882e+09
#
# [1930 rows x 12 columns]

# %%
sns.pairplot(result_df);

# %%
sns.heatmap(result_df.corr(), annot=True);

# %%
result_df[['Market cap BTC', 'Volume (24h)']].plot(figsize = (16, 8))
plt.ylabel('Price (USD)')
plt.yscale('log')
plt.title('Volume of transactions')
# Out:
# Text(0.5, 1.0, 'Volume of transactions')

# %%
result_df
# Out:
#                        Market cap  Volume (24h)  Market cap BTC  \
# DateTime
# 2013-04-29 02:00:00  1.583440e+09  0.000000e+00    1.491167e+09
# 2013-05-01 02:00:00  1.637390e+09  0.000000e+00    1.542817e+09
# 2013-05-03 02:00:00  1.275410e+09  0.000000e+00    1.180068e+09
# 2013-05-05 02:00:00  1.335380e+09  0.000000e+00    1.254762e+09
# 2013-05-07 02:00:00  1.313900e+09  0.000000e+00    1.248467e+09
# ...                           ...           ...             ...
# 2023-11-15 01:00:00  1.364502e+12  6.540533e+10    6.946959e+11
# 2023-11-17 01:00:00  1.381335e+12  7.162194e+10    7.068137e+11
# 2023-11-19 01:00:00  1.390730e+12  4.060731e+10    7.151086e+11
# 2023-11-21 01:00:00  1.417561e+12  5.502937e+10    7.324551e+11
# 2023-11-23 01:00:00  1.418535e+12  5.941507e+10    7.315725e+11
#
#                      Market cap ETH  Market cap USDT  Market cap BNB  \
# DateTime
# 2013-04-29 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-01 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-03 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-05 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-07 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# ...                             ...              ...             ...
# 2023-11-15 01:00:00    2.380468e+11     8.709902e+10    3.675435e+10
# 2023-11-17 01:00:00    2.359238e+11     8.745069e+10    3.683906e+10
# 2023-11-19 01:00:00    2.360777e+11     8.773070e+10    3.716176e+10
# 2023-11-21 01:00:00    2.431773e+11     8.776159e+10    3.847786e+10
# 2023-11-23 01:00:00    2.481826e+11     8.834055e+10    3.581576e+10
#
#                      Market cap XRP  Market cap USDC  Market cap SOL  \
# DateTime
# 2013-04-29 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-01 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-03 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-05 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-07 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# ...                             ...              ...             ...
# 2023-11-15 01:00:00    3.378657e+10     2.389193e+10    2.400899e+10
# 2023-11-17 01:00:00    3.288629e+10     2.417387e+10    2.447972e+10
# 2023-11-19 01:00:00    3.283192e+10     2.441563e+10    2.474817e+10
# 2023-11-21 01:00:00    3.292038e+10     2.451585e+10    2.391605e+10
# 2023-11-23 01:00:00    3.286810e+10     2.440988e+10    2.436149e+10
#
#                      Market cap ADA  Market cap DOGE  Market cap TRX
# DateTime
# 2013-04-29 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-01 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-03 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-05 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# 2013-05-07 02:00:00    0.000000e+00     0.000000e+00    0.000000e+00
# ...                             ...              ...             ...
# 2023-11-15 01:00:00    1.262335e+10     1.027658e+10    9.068946e+09
# 2023-11-17 01:00:00    1.311623e+10     1.125309e+10    9.078347e+09
# 2023-11-19 01:00:00    1.332426e+10     1.140690e+10    9.129964e+09
# 2023-11-21 01:00:00    1.343389e+10     1.105198e+10    8.960598e+09
# 2023-11-23 01:00:00    1.343348e+10     1.075476e+10    8.968882e+09
#
# [1930 rows x 12 columns]

# %%
result_df['MA200'] = result_df['Market cap'].rolling(window = 200).mean()

# %%
result_df['MA200/BTC'] = result_df['Market cap BTC'].rolling(window = 200).mean()
result_df.tail()
# Out:
#                        Market cap  Volume (24h)  Market cap BTC  \
# DateTime
# 2023-11-15 01:00:00  1.364502e+12  6.540533e+10    6.946959e+11
# 2023-11-17 01:00:00  1.381335e+12  7.162194e+10    7.068137e+11
# 2023-11-19 01:00:00  1.390730e+12  4.060731e+10    7.151086e+11
# 2023-11-21 01:00:00  1.417561e+12  5.502937e+10    7.324551e+11
# 2023-11-23 01:00:00  1.418535e+12  5.941507e+10    7.315725e+11
#
#                      Market cap ETH  Market cap USDT  Market cap BNB  \
# DateTime
# 2023-11-15 01:00:00    2.380468e+11     8.709902e+10    3.675435e+10
# 2023-11-17 01:00:00    2.359238e+11     8.745069e+10    3.683906e+10
# 2023-11-19 01:00:00    2.360777e+11     8.773070e+10    3.716176e+10
# 2023-11-21 01:00:00    2.431773e+11     8.776159e+10    3.847786e+10
# 2023-11-23 01:00:00    2.481826e+11     8.834055e+10    3.581576e+10
#
#                      Market cap XRP  Market cap USDC  Market cap SOL  \
# DateTime
# 2023-11-15 01:00:00    3.378657e+10     2.389193e+10    2.400899e+10
# 2023-11-17 01:00:00    3.288629e+10     2.417387e+10    2.447972e+10
# 2023-11-19 01:00:00    3.283192e+10     2.441563e+10    2.474817e+10
# 2023-11-21 01:00:00    3.292038e+10     2.451585e+10    2.391605e+10
# 2023-11-23 01:00:00    3.286810e+10     2.440988e+10    2.436149e+10
#
#                      Market cap ADA  Market cap DOGE  Market cap TRX  \
# DateTime
# 2023-11-15 01:00:00    1.262335e+10     1.027658e+10    9.068946e+09
# 2023-11-17 01:00:00    1.311623e+10     1.125309e+10    9.078347e+09
# 2023-11-19 01:00:00    1.332426e+10     1.140690e+10    9.129964e+09
# 2023-11-21 01:00:00    1.343389e+10     1.105198e+10    8.960598e+09
# 2023-11-23 01:00:00    1.343348e+10     1.075476e+10    8.968882e+09
#
#                             MA200     MA200/BTC
# DateTime
# 2023-11-15 01:00:00  1.071091e+12  4.893919e+11
# 2023-11-17 01:00:00  1.073375e+12  4.910909e+11
# 2023-11-19 01:00:00  1.075721e+12  4.928296e+11
# 2023-11-21 01:00:00  1.078212e+12  4.946520e+11
# 2023-11-23 01:00:00  1.080671e+12  4.964619e+11

# %%
result_df['MA200/ETH'] = result_df['Market cap ETH'].rolling(window = 200).mean()

# %%
result_df['MA200/USDT'] = result_df['Market cap USDT'].rolling(window = 200).mean()

# %%
result_df['MA200/USDT']
# Out:
# DateTime
# 2013-04-29 02:00:00             NaN
# 2013-05-01 02:00:00             NaN
# 2013-05-03 02:00:00             NaN
# 2013-05-05 02:00:00             NaN
# 2013-05-07 02:00:00             NaN
#                            ...
# 2023-11-15 01:00:00    7.698678e+10
# 2023-11-17 01:00:00    7.708217e+10
# 2023-11-19 01:00:00    7.717872e+10
# 2023-11-21 01:00:00    7.727539e+10
# 2023-11-23 01:00:00    7.737491e+10
# Name: MA200/USDT, Length: 1930, dtype: float64

# %%
result_df[['Market cap BTC', 'MA200/BTC']].plot(figsize = (16, 8))
plt.ylabel('Price (USD)')
plt.title('Price & 200 Day MA')
# Out:
# Text(0.5, 1.0, 'Price & 200 Day MA')

# %%
result_df['MM'] = result_df['Market cap BTC'] / result_df['MA200/BTC']
result_df['MM'].plot(figsize = (16, 8), grid = True, color = 'black', lw = 0.8)
plt.title('Mayer Multiple')
plt.ylabel('Price / 200MA')
# Out:
# Text(0, 0.5, 'Price / 200MA')

# %%
result_df['NVT'] = result_df['Market cap'] / result_df['Volume (24h)']

# %%
result_df['NVT'].plot(figsize = (16, 8), grid = True, color = 'green', lw = 0.8)
plt.title('NVT-value')
plt.ylabel('NVT')
# Out:
# Text(0, 0.5, 'NVT')

# %%
result_df['NVT-smooth'] = result_df['NVT'].rolling(window = 14).mean()
result_df['NVT-smooth'].plot(figsize = (16, 8), lw = 0.8, grid = True)
plt.title('14MA NVT')
plt.ylabel('NVT')
# Out:
# Text(0, 0.5, 'NVT')

# %%
result_df = result_df.drop(columns="NVT")

# %%
result_df.to_csv("Dfmcap.csv", index=False)

# %%
from pandas.plotting import autocorrelation_plot

autocorrelation_plot(result_df["Market cap BTC"]);
